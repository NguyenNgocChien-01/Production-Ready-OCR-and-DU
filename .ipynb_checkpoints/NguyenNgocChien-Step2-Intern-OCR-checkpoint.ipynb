# %% [markdown]
# # Production-Ready OCR &
# # Document Understanding
# # Mastery Challenge

# %% [markdown]
# ## Step 2
# ## Research/Learn
# ### Design Schema:

# %%
# 1. Invoice
{
  "type": "invoice",
  "data": {
    "invoice_number": "string",
    "customer_name": "string",
    "customer_id": "string",
    "service_table": {
        "amout": "float",
        "name": "string",
        "price": "string"
    },
    "issue_date": "YYYY-MM-DD",
    "total_amount": "number",
    "currency": "string"
  }
}
# 2. Passport
{
  "type": "passport",
  "data": {
    "passport_number": "string",
    "full_name": "string",
    "image": "string",
    "nationality": "string",
    "date_of_birth": "YYYY-MM-DD",
    "gender": "string",
    "expiry_date": "YYYY-MM-DD"
  }
}

# 3. Catificates
{
  "type": "certificate",
  "data": {
    "certificate_id": "string",
    "holder_name": "string",
    "image": "string",
    "certificate_type": "string",
    "issuing_organization": "string",
    "issue_date": "YYYY-MM-DD"
  }
}
# 4. Driver lisence
{
  "type": "driver_license",
  "data": {
    "license_number": "string",
    "full_name": "string",
    "image": "string",
    "date_of_birth": "YYYY-MM-DD",
    "vehicle_class": "string",
    "expiry_date": "YYYY-MM-DD"
  }
}

# 5. Card ID
{
  "type": "id_card",
  "data": {
    "id_number": "string",
    "image": "string",
    "full_name": "string",
    "date_of_birth": "YYYY-MM-DD",
    "gender": "string",
    "nationality": "string",
    "place_of_origin": "string",
    "place_of_residence": "string",
    "expiry_date": "YYYY-MM-DD",
    "issue_date": "YYYY-MM-DD"
  }
}

# Can add confidence for items

# %% [markdown]
# ## Milestone:
# Complete schema library + “unknown” fallback logic documented.

# %%
With unknow: 
Cach 1. Yc nguoi dung chon loai tai lieu, neu ko khop thi yc chon lai
Cach 2.
